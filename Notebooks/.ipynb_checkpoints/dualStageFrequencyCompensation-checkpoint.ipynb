# %% [markdown]
# # Frequency compensation
# In this notebook we will demonstrate the application of frequency compensation to establish a MFM low-pass servo function.
# We will use the dual-stage amplifier with EKV models from the previous notebook as starting point.
# The servo function of the uncompensated amplifier has a second-order low-pass character with two complex poles with a quality factor larger than $\frac{1}{2}\sqrt{2}$. The small-signal diagram of this amplifier is shown below.

# %%
import SLiCAP as sl
import sympy as sp
sl.initProject('Hearing loop', notebook=True)
sl.img2html("dualStageEKV.svg", 600)
specs     = sl.csv2specs("dualStage.csv")
spec_dict = sl.specs2dict(specs)
# Out:
# Compiling library: SLiCAP.lib.
# Compiling library: SLiCAPmodels.lib.

# %% [markdown]
# ## Phantom-zero compensation
# Frequency compensation with phantom-zeros is by far the best method because of all methods it has:
# 1. a low noise penalty
# 2. a low power penalty
# 3. the lowest energy storage penalty
# 4. the lowest distortion penalty (phantom-zero compensation can reduce the distortion)
# 5. a low bandwidth penalty
# ## Implementation of phantom zeros
# Phantom zeros can be effectively implemented as follows:
# 1. If elements of the feedback network(s) attenuate the loop gain at the phantom-zero frequency
#   - By creating a high-pass transfer in elements of the feedback network that
# 2. If the source impedance attenuates the loop gain at the frequency of the phantom zero:
#    - In case of parallel feedback at the input port of the amplifier, by inserting an impedance in series with the source that establishes a low-pass transfer from the source to the amplifier
#    - In case of series feedback at the input port of the amplifier, by inserting an impedance in parallel with the source that establishes a low-pass transfer from the source to the amplifier
# 3. If the load impedance attenuates the loop gain at the frequency of the phantom zero:
#    - In case of parallel feedback at the output port of the amplifier, by inserting an impedance in series with the load that establishes a low-pass transfer from the amplifier to the load
#    - In case of series feedback at the output port of the amplifier, by inserting an impedance in parallel with the load that establishes a low-pass transfer from the amplifier to the load
# ## Frequency of the phantom zero(s)
# An MFM low-pass roll-off of a servo function of a feedback amplifier with two loop gain poles with a negative real part requires:
# \begin{equation}
# p_1 + p_2 = -\sqrt{2 \left( 1-L_{DC} \right) p_1 p_2}
# \end{equation}
# The frequency of the phantom zero:
# \begin{equation}
# z = -\frac{\left( 1-L_{DC} \right) p_1 p_2}{\sqrt{2 \left( 1-L_{DC} \right) p_1 p_2} + p_1 + p_2}
# \end{equation}

# %% [markdown]
# ## Frequency compensation of the dual-stage amplifier
# 1. An MFM low-pass characteristic of the servo function requires compensation because the quality factor of the poles exceeds $\frac{1}{2}\sqrt{2}$.
# 2. The required phantom zero frequency is approximately:

# %%
# %store -r EKV_PZ_LG
L_DC  = EKV_PZ_LG.DCvalue
poles = EKV_PZ_LG.poles
zeros = EKV_PZ_LG.zeros
p_1   = poles[3]
p_2   = poles[4]
z = -((1-L_DC)*p_1*p_2)/(sp.sqrt(2*(1-L_DC)*p_1*p_2) + p_1 + p_2)
sl.eqn2html("z", z, units="rad/s")
# Out:
# \begin{equation}
# z=-185.6\cdot 10^{6}\,\left[ \mathrm{\frac{rad}{s}}\right]
# \end{equation}

# %% [markdown]
# 3. At this frequency, the load capacitance causes a significant attenuation in the loop gain. Hence, insertion of a resistor
# between the output of the amplifier and the load establishes a low-pass transfer in the asymptotic gain and an effective zero
# in the loop gain. Its resistance must be:
# \begin{equation}
# R_{phz} = - \frac{1}{z C_L}:
# \end{equation}

# %%
Rphz = -1/(z * spec_dict["C_L"].value)
specs.append(sl.specItem("R_phz",
                         value = Rphz,
                         description = "Phantom-zero resistance",
                         units = "Omega",
                         specType = "design"))
sl.eqn2html("R_phz", Rphz, units="Ohm")
# Out:
# \begin{equation}
# R_{phz}=538.8\,\left[ \mathrm{\Omega}\right]
# \end{equation}

# %% [markdown]
# ## Verification

# %%
cir = sl.makeCircuit("kicad/A1/dualStageEKVcompensated.kicad_sch")
sl.specs2circuit(specs, cir)
sl.img2html("dualStageEKVcompensated.svg", 600)
# Out:
# Creating netlist of kicad/A1/dualStageEKVcompensated.kicad_sch using KiCAD
# Creating drawing-size SVG and PDF images of kicad/A1/dualStageEKVcompensated.kicad_sch
# Plotted to '/home/anton/DATA/www/SEDwebsite/_build/SEDwebsite/EE4109-2025-2026/designExample/HearingLoop/Notebooks/img/dualStageEKVcompensated.svg'.
# Done.
# Checking netlist: cir/dualStageEKVcompensated.cir
# <figure><img src="img/dualStageEKVcompensated.svg" alt="" style="width:600px">
# </figure>

# %%
gainPZ = sl.doPZ(cir, pardefs="circuit", numeric=True)
sl.pz2html(gainPZ)
# Out:
# <h2>PZ  analysis results</h2>
# <h3>Gain type: gain</h3>
# <p>DC value = $17.2$</p>
# <table><tr><th>pole</th><th>Re [Hz]</th><th>Im [Hz]</th><th>Mag [Hz]</th><th>Q</th></tr>
# <tr><td>p<sub>1</sub></td><td>$-600.8$</td><td></td><td>$600.8$</td><td></td></tr>
# <tr><td>p<sub>2</sub></td><td>$-106.5\cdot 10^{3}$</td><td>$106.6\cdot 10^{3}$</td><td>$150.7\cdot 10^{3}$</td><td>$0.7076$</td></tr>
# <tr><td>p<sub>3</sub></td><td>$-106.5\cdot 10^{3}$</td><td>$-106.6\cdot 10^{3}$</td><td>$150.7\cdot 10^{3}$</td><td>$0.7076$</td></tr>
# <tr><td>p<sub>4</sub></td><td>$-26.71\cdot 10^{6}$</td><td>$26.13\cdot 10^{6}$</td><td>$37.36\cdot 10^{6}$</td><td>$0.6995$</td></tr>
# <tr><td>p<sub>5</sub></td><td>$-26.71\cdot 10^{6}$</td><td>$-26.13\cdot 10^{6}$</td><td>$37.36\cdot 10^{6}$</td><td>$0.6995$</td></tr>
# <tr><td>p<sub>6</sub></td><td>$-8.738\cdot 10^{9}$</td><td></td><td>$8.738\cdot 10^{9}$</td><td></td></tr>
# </table>
# <table><tr><th>zero</th><th>Re [Hz]</th><th>Im [Hz]</th><th>Mag [Hz]</th><th>Q</th></tr>
# <tr><td>z<sub>1</sub></td><td>$204.7\cdot 10^{6}$</td><td>$727.3\cdot 10^{6}$</td><td>$755.5\cdot 10^{6}$</td><td>$1.846$</td></tr>
# <tr><td>z<sub>2</sub></td><td>$204.7\cdot 10^{6}$</td><td>$-727.3\cdot 10^{6}$</td><td>$755.5\cdot 10^{6}$</td><td>$1.846$</td></tr>
# <tr><td>z<sub>3</sub></td><td>$-10.51\cdot 10^{3}$</td><td></td><td>$10.51\cdot 10^{3}$</td><td></td></tr>
# </table>

# %%
gainLaplace = sl.doLaplace(cir, pardefs="circuit", numeric=True)
sl.plotSweep("dualStageMagComp", "Gain of compendated dual-stage amplifier", gainLaplace, 100, 1e9, 500)

# %%
sl.img2html("dualStageMagComp.svg", 800)
# Out:
# <figure><img src="img/dualStageMagComp.svg" alt="" style="width:800px">
# </figure>

# %%
sl.specs2html(specs, ["design"])
# Out:
# <h3>design specification</h3>
# <table><a id="table_design"></a><caption>Table design specification </caption><tr><th class="left">symbol</th><th class="left">description</th><th class="left">value</th><th class="left">units</th></tr>
# <td class="left">$B_{i1}$</td><td class="left">Relative budget for the current through the feedback network</td><td class="left">$0.1$</td><td></td></tr>
# <td class="left">$B_{n1}$</td><td class="left">Relative budget for contribution of source, termination and feedback network to the total weighted output noise</td><td class="left">$0.4$</td><td></td></tr>
# <td class="left">$C_{i}$</td><td class="left">Integrator capacitance</td><td class="left">$\frac{\tau_{i}}{R_{f}}$</td><td class="left">$\mathrm{F}$</td></tr>
# <td class="left">$ID_{1}$</td><td class="left">Output stage operating current</td><td class="left">$-8.052\cdot 10^{-6}$</td><td class="left">$\mathrm{A}$</td></tr>
# <td class="left">$ID_{2}$</td><td class="left">Output stage operating current</td><td class="left">$7.143\cdot 10^{-6}$</td><td class="left">$\mathrm{A}$</td></tr>
# <td class="left">$I_{iP1}$</td><td class="left">P-channel input stage current at minimum transconductance</td><td class="left">$-2.009\cdot 10^{-6}$</td><td class="left">$\mathrm{A}$</td></tr>
# <td class="left">$I_{iP2}$</td><td class="left">P-channel input stage current at minimum g-c product</td><td class="left">$-4.026\cdot 10^{-6}$</td><td class="left">$\mathrm{A}$</td></tr>
# <td class="left">$L_{1}$</td><td class="left">Input stage transistor length</td><td class="left">$434.8\cdot 10^{-9}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$L_{2}$</td><td class="left">Output stage transistor length</td><td class="left">$180\cdot 10^{-9}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$L_{iP1}$</td><td class="left">P-channel input stage length at minimum transconductance</td><td class="left">$65.57\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$L_{iP2}$</td><td class="left">P-channel input stage length at minimum g-c product</td><td class="left">$217.4\cdot 10^{-9}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$R_{b}$</td><td class="left">Bias resistance</td><td class="left">$\frac{0.5}{\pi C_{i} f_{min}}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$R_{f}$</td><td class="left">Selected value of R_f</td><td class="left">$7.500\cdot 10^{3}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$R_{f max}$</td><td class="left">Maximum value of R_f</td><td class="left">$7.542\cdot 10^{3}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$R_{f min}$</td><td class="left">Minimum value of R_f</td><td class="left">$1.393\cdot 10^{3}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$R_{phz}$</td><td class="left">Phantom-zero resistance</td><td class="left">$538.8$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$W_{1}$</td><td class="left">Input stage transistor width</td><td class="left">$23.04\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$W_{2}$</td><td class="left">Output stage transistor width</td><td class="left">$10\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$W_{iP1}$</td><td class="left">P-channel input stage width at minimum transconductance</td><td class="left">$0.001734$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$W_{iP2}$</td><td class="left">P-channel input stage width at minimum g-c product</td><td class="left">$11.52\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$c_{issP1}$</td><td class="left">c_iss P-channel input stage at minimum transconductance</td><td class="left">$423.7\cdot 10^{-12}$</td><td class="left">$\mathrm{F}$</td></tr>
# <td class="left">$c_{issP2}$</td><td class="left">c_iss P-channel input stage at minimum g-c product</td><td class="left">$25.41\cdot 10^{-15}$</td><td class="left">$\mathrm{F}$</td></tr>
# <td class="left">$g_{mP1}$</td><td class="left">Minimum transconductance P channel input stage</td><td class="left">$42.28\cdot 10^{-6}$</td><td class="left">$\mathrm{S}$</td></tr>
# <td class="left">$g_{mP2}$</td><td class="left">Transconductance P channel input stage at minimum g-c product</td><td class="left">$84.70\cdot 10^{-6}$</td><td class="left">$\mathrm{S}$</td></tr>
# </table>

# %% [markdown]
# ### Circuit parameters

# %%
sl.params2html(cir)
# Out:
# <table><caption>Table: Parameter definitions in 'dualStageEKVcompensated'.</caption>
# <tr><th class="left">Name</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">$B_{i1}$</td><td class="left">$0.1$</td><td class="left">$0.1$</td></tr>
# <tr><td class="left">$B_{n1}$</td><td class="left">$0.4$</td><td class="left">$0.4$</td></tr>
# <tr><td class="left">$CGBO_{N18}$</td><td class="left">$1000\cdot 10^{-15}$</td><td class="left">$1000\cdot 10^{-15}$</td></tr>
# <tr><td class="left">$CGBO_{P18}$</td><td class="left">$1000\cdot 10^{-15}$</td><td class="left">$1000\cdot 10^{-15}$</td></tr>
# <tr><td class="left">$CGSO_{N18}$</td><td class="left">$300\cdot 10^{-12}$</td><td class="left">$300\cdot 10^{-12}$</td></tr>
# <tr><td class="left">$CGSO_{P18}$</td><td class="left">$300\cdot 10^{-12}$</td><td class="left">$300\cdot 10^{-12}$</td></tr>
# <tr><td class="left">$CJB_{0 N18}$</td><td class="left">$1000\cdot 10^{-6}$</td><td class="left">$1000\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$CJB_{0 P18}$</td><td class="left">$1000\cdot 10^{-6}$</td><td class="left">$1000\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$C_{L}$</td><td class="left">$10\cdot 10^{-12}$</td><td class="left">$10\cdot 10^{-12}$</td></tr>
# <tr><td class="left">$C_{OX N18}$</td><td class="left">$\frac{\epsilon_{0} \epsilon_{SiO2}}{TOX_{N18}}$</td><td class="left">$0.008422$</td></tr>
# <tr><td class="left">$C_{OX P18}$</td><td class="left">$\frac{\epsilon_{0} \epsilon_{SiO2}}{TOX_{P18}}$</td><td class="left">$0.008422$</td></tr>
# <tr><td class="left">$C_{i}$</td><td class="left">$\frac{\tau_{i}}{R_{f}}$</td><td class="left">$2.142\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$C_{s}$</td><td class="left">$9.382\cdot 10^{-12}$</td><td class="left">$9.382\cdot 10^{-12}$</td></tr>
# <tr><td class="left">$DIN_{A}$</td><td class="left">$\frac{1.872 \cdot 10^{8} f^{4}}{\left(\left(f^{2} + 1.16 \cdot 10^{4}\right) \left(f^{2} + 5.445 \cdot 10^{5}\right)\right)^{0.5} \left(f^{2} + 424.4\right) \left(f^{2} + 1.487 \cdot 10^{8}\right)}$</td><td class="left">$\frac{1.872 \cdot 10^{8} f^{4}}{\left(\left(f^{2} + 1.16 \cdot 10^{4}\right) \left(f^{2} + 5.445 \cdot 10^{5}\right)\right)^{0.5} \left(f^{2} + 424.4\right) \left(f^{2} + 1.487 \cdot 10^{8}\right)}$</td></tr>
# <tr><td class="left">$DVTDIBL_{N18}$</td><td class="left">$-0.008$</td><td class="left">$-0.008$</td></tr>
# <tr><td class="left">$DVTDIBL_{P18}$</td><td class="left">$0.01$</td><td class="left">$0.01$</td></tr>
# <tr><td class="left">$DVTIDBLEXP_{N18}$</td><td class="left">$3$</td><td class="left">$3$</td></tr>
# <tr><td class="left">$DVTIDBLEXP_{P18}$</td><td class="left">$3$</td><td class="left">$3$</td></tr>
# <tr><td class="left">$E_{CRIT N18}$</td><td class="left">$5.600\cdot 10^{6}$</td><td class="left">$5.600\cdot 10^{6}$</td></tr>
# <tr><td class="left">$E_{CRIT P18}$</td><td class="left">$14\cdot 10^{6}$</td><td class="left">$14\cdot 10^{6}$</td></tr>
# <tr><td class="left">$ID_{1}$</td><td class="left">$-8.052\cdot 10^{-6}$</td><td class="left">$-8.052\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$ID_{2}$</td><td class="left">$7.143\cdot 10^{-6}$</td><td class="left">$7.143\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$I_{0 N18}$</td><td class="left">$2 C_{OX N18} N_{s N18} U_{T}^{2} u_{0 N18}$</td><td class="left">$641.4\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$I_{0 P18}$</td><td class="left">$2 C_{OX P18} N_{s P18} U_{T}^{2} u_{0 P18}$</td><td class="left">$135.6\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$I_{iP1}$</td><td class="left">$-2.009\cdot 10^{-6}$</td><td class="left">$-2.009\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$I_{iP2}$</td><td class="left">$-4.026\cdot 10^{-6}$</td><td class="left">$-4.026\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$L_{1}$</td><td class="left">$434.8\cdot 10^{-9}$</td><td class="left">$434.8\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$L_{2}$</td><td class="left">$180\cdot 10^{-9}$</td><td class="left">$180\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$LDS_{N18}$</td><td class="left">$180\cdot 10^{-9}$</td><td class="left">$180\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$LDS_{P18}$</td><td class="left">$180\cdot 10^{-9}$</td><td class="left">$180\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$L_{iP1}$</td><td class="left">$65.57\cdot 10^{-6}$</td><td class="left">$65.57\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$L_{iP2}$</td><td class="left">$217.4\cdot 10^{-9}$</td><td class="left">$217.4\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$L_{min N18}$</td><td class="left">$180\cdot 10^{-9}$</td><td class="left">$180\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$L_{min P18}$</td><td class="left">$180\cdot 10^{-9}$</td><td class="left">$180\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$L_{s}$</td><td class="left">$0.12$</td><td class="left">$0.12$</td></tr>
# <tr><td class="left">$N_{s N18}$</td><td class="left">$1.35$</td><td class="left">$1.35$</td></tr>
# <tr><td class="left">$N_{s P18}$</td><td class="left">$1.35$</td><td class="left">$1.35$</td></tr>
# <tr><td class="left">$P_{max}$</td><td class="left">$1000\cdot 10^{-6}$</td><td class="left">$1000\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$R_{b}$</td><td class="left">$\frac{0.5}{\pi C_{i} f_{min}}$</td><td class="left">$123.9\cdot 10^{3}$</td></tr>
# <tr><td class="left">$R_{f}$</td><td class="left">$7.500\cdot 10^{3}$</td><td class="left">$7.500\cdot 10^{3}$</td></tr>
# <tr><td class="left">$R_{f max}$</td><td class="left">$7.542\cdot 10^{3}$</td><td class="left">$7.542\cdot 10^{3}$</td></tr>
# <tr><td class="left">$R_{f min}$</td><td class="left">$1.393\cdot 10^{3}$</td><td class="left">$1.393\cdot 10^{3}$</td></tr>
# <tr><td class="left">$R_{phz}$</td><td class="left">$538.8$</td><td class="left">$538.8$</td></tr>
# <tr><td class="left">$R_{s}$</td><td class="left">$875$</td><td class="left">$875$</td></tr>
# <tr><td class="left">$R_{t}$</td><td class="left">$79.97\cdot 10^{3}$</td><td class="left">$79.97\cdot 10^{3}$</td></tr>
# <tr><td class="left">$T$</td><td class="left">$300$</td><td class="left">$300$</td></tr>
# <tr><td class="left">$TOX_{N18}$</td><td class="left">$4.100\cdot 10^{-9}$</td><td class="left">$4.100\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$TOX_{P18}$</td><td class="left">$4.100\cdot 10^{-9}$</td><td class="left">$4.100\cdot 10^{-9}$</td></tr>
# <tr><td class="left">$T_{max}$</td><td class="left">$50$</td><td class="left">$50$</td></tr>
# <tr><td class="left">$T_{min}$</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">$\Theta_{N18}$</td><td class="left">$0.28$</td><td class="left">$0.28$</td></tr>
# <tr><td class="left">$\Theta_{P18}$</td><td class="left">$0.35$</td><td class="left">$0.35$</td></tr>
# <tr><td class="left">$U_{T}$</td><td class="left">$\frac{T k}{q}$</td><td class="left">$0.02585$</td></tr>
# <tr><td class="left">$VAL_{N18}$</td><td class="left">$20\cdot 10^{6}$</td><td class="left">$20\cdot 10^{6}$</td></tr>
# <tr><td class="left">$VAL_{P18}$</td><td class="left">$20\cdot 10^{6}$</td><td class="left">$20\cdot 10^{6}$</td></tr>
# <tr><td class="left">$V_{ADC high}$</td><td class="left">$0.9$</td><td class="left">$0.9$</td></tr>
# <tr><td class="left">$V_{ADC low}$</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">$V_{DD max}$</td><td class="left">$1.3$</td><td class="left">$1.3$</td></tr>
# <tr><td class="left">$V_{DD min}$</td><td class="left">$1.1$</td><td class="left">$1.1$</td></tr>
# <tr><td class="left">$V_{ns}$</td><td class="left">$1.496\cdot 10^{-6}$</td><td class="left">$1.496\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$V_{onoise}$</td><td class="left">$10.62\cdot 10^{-6}$</td><td class="left">$10.62\cdot 10^{-6}$</td></tr>
# <tr><td class="left">$Vi_{pp}$</td><td class="left">$0.1072$</td><td class="left">$0.1072$</td></tr>
# <tr><td class="left">$Vth_{N18}$</td><td class="left">$0.42$</td><td class="left">$0.42$</td></tr>
# <tr><td class="left">$Vth_{P18}$</td><td class="left">$-0.42$</td><td class="left">$-0.42$</td></tr>
# <tr><td class="le
