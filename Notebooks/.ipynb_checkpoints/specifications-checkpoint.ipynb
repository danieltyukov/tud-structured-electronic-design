# %% [markdown]
# # Specifications

# %%
import SLiCAP as sl
from sympy import pi, sqrt, log, Abs
sl.initProject('Specifications', notebook=True)
# Out:
# Generating project configuration file: SLiCAP.ini.
#
# Compiling library: SLiCAP.lib.
# Compiling library: SLiCAPmodels.lib.

# %% [markdown]
# ## Functional model
# Below the functional model of the hearing loop receive coil amplifier with source, load and noise weighting function.

# %%
cir = sl.makeCircuit("kicad/A1/fumo.kicad_sch")
sl.img2html("fumo.svg", 800)
# Out:
# Creating netlist of kicad/A1/fumo.kicad_sch using KiCAD
# Creating drawing-size SVG and PDF images of kicad/A1/fumo.kicad_sch
# Plotted to '/home/anton/DATA/www/SEDwebsite/_build/SEDwebsite/EE4109-2025-2026/designExample/HearingLoop/Notebooks/img/fumo.svg'.
# Done.
# Checking netlist: cir/fumo.cir
# <figure><img src="img/fumo.svg" alt="" style="width:800px">
# </figure>

# %% [markdown]
# ## System and component specifications

# %%
# Performance specifications
SPL             = 20E-6     # 0dB SPL level in Pa
n_SPL           = 30        # Allowed SPL noise level
SPL_max         = 110       # Peak sound pressure level 
f_min           = 600       # Low -3dB cut-off frequency
f_max           = 6000      # High -3dB cut-off frequency
f_fp            = 5000      # Maximum full-power frequency

# Interface specifications
V_ADC_high      = 0.9      # Full-scale input voltage ADC
V_ADC_low       = 0        # Zero-scale input voltage ADC
A_mic           = -35.5    # Typical microphone sensitivity in dBV/Pa
H_ref           = 90       # dB/(A/m) inductive loop reference
f_ref           = 1000     # Reference frequency for receive coil sensitivity
f_res           = 0.15e6   # Minimum receive-coil self-resonant frequency
A_L             = -59.4    # dBV/(A/m) typical open-circuit receive coil sensitivity at f_ref
Rs              = 875      # Typical receive coil resistance
Ls              = 0.12     # Typical receive coil inductance
CL              = 10e-12   # Load capacitance

# Cost factors
P_max           = 1e-3     # Maximum power dissipation at maximum supply voltage 
V_DD_max        = 1.3      # Maximum supply voltage
V_DD_min        = 1.1      # Minimum supply voltage    

# Environmental conditions
T_min           = 0        # Minimum operating temperature
T_max           = 50       # Maximum operating temperature

specs = []

# %% [markdown]
# ## Derived specifications

# %% [markdown]
# The parasitic parallel receive coil capacitance can be calculated from the self-resonance frequency as:
# \begin{equation}
# C_s = \frac{1}{\left( 2\pi f_\mathrm{res}\right)^2 L_s}
# \end{equation}

# %%
Cs              = 1/((2 *pi * f_res)**2 * Ls)
sl.eqn2html("C_s", Cs, units="F")
# Out:
# \begin{equation}
# C_{s}=9.382\cdot 10^{-12}\,\left[ \mathrm{F}\right]
# \end{equation}

# %% [markdown]
# Damping of this resonance can be achieved by placing a resistor in parallel with the inductor.
# For critical damping ($Q=\frac{1}{2}\sqrt{2}$) the resistance $R_t$ can be obtained as
# \begin{equation}
# R_t=\frac{\sqrt{2}}{4\pi f_\mathrm{res}C_s}
# \end{equation}

# %%
Rt              = sqrt(2)/(4 * pi * f_res * Cs)
sl.eqn2html("R_t", Rt, units="Ohm")
# Out:
# \begin{equation}
# R_{t}=79.97\cdot 10^{3}\,\left[ \mathrm{\Omega}\right]
# \end{equation}

# %% [markdown]
# The DIN-A weighted output noise of the receive coil amplifier may correspond to 30 dBSPL (microphone output):
# \begin{equation}
# V_\mathrm{onoise} = 20\cdot 10^{-6} 10^{\left( A_\mathrm{mic} + n_\mathrm{SPL}\right)/20}
# \end{equation}

# %%
V_onoise        = SPL * 10**((A_mic + n_SPL)/20)
sl.eqn2html("V_onoise", V_onoise, units="V")
# Out:
# \begin{equation}
# V_{onoise}=10.62\cdot 10^{-6}\,\left[ \mathrm{V}\right]
# \end{equation}

# %% [markdown]
# The peak microphone output voltage at peak SPL is found as
#
# \begin{equation}
# V_\mathrm{mic} = 20 \cdot 10^{-6} \cdot 10^{\left( A_\mathrm{mic}+ \mathrm{SPL_{max}}\right)/20}
# \end{equation}

# %%
V_mic           = SPL * 10**((A_mic + SPL_max)/20)
sl.eqn2html("V_mic", V_mic, units="V")
# Out:
# \begin{equation}
# V_{mic}=0.1062\,\left[ \mathrm{V}\right]
# \end{equation}

# %% [markdown]
# The peak receive coil output voltage at reference frequency is
# \begin{equation}
# V_i = 10^{\left( A_L + \mathrm{SPL_{max}} - H_\mathrm{ref}\right)/20}
# \end{equation}

# %%
Vi             = 10**((A_L + SPL_max - H_ref)/20)
sl.eqn2html("V_i", Vi, units="V")
# Out:
# \begin{equation}
# V_{i}=0.01072\,\left[ \mathrm{V}\right]
# \end{equation}

# %% [markdown]
# The required integrator time constant, such that the receive-coil amplifier output equals the microphone output, can be calculated as
# \begin{equation}
# \tau_i = \frac{V_i}{2\pi f_\mathrm{ref} V_\mathrm{mic}}
# \end{equation}

# %%
tau_i           = Vi/(2*pi*f_ref*V_mic)
sl.eqn2html("tau_i", tau_i, units="s")
# Out:
# \begin{equation}
# \tau_{i}=16.06\cdot 10^{-6}\,\left[ \mathrm{s}\right]
# \end{equation}

# %% [markdown]
# The peak-peak receive coil output voltage at maximum full-power frequency is found as
# \begin{equation}
# V_{i_\mathrm{pp}} = 2 V_i \frac{f_\mathrm{fp}}{f_\mathrm{ref}}
# \end{equation}

# %%
Vi_pp           = 2 * Vi * f_fp/f_ref
sl.eqn2html("V_i_pp", Vi_pp, units="V")
# Out:
# \begin{equation}
# V_{i pp}=0.1072\,\left[ \mathrm{V}\right]
# \end{equation}

# %% [markdown]
# ## Create a SLiCAP design database

# %%
# source impedance specification

specs.append(
    sl.specItem(
        "L_s",
        description = "Source inductance",
        value       = Ls,
        units       = "H",
        specType    = "Interface",
    )
)
specs.append(
    sl.specItem(
        "R_s",
        description = "Source resistance",
        value       = Rs,
        units       = "Omega",
        specType    = "Interface",
    )
)
specs.append(
    sl.specItem(
        "C_s",
        description = "Source capacitance",
        value       = Cs,
        units       = "F",
        specType    = "Interface",
    )
)
specs.append(
    sl.specItem(
        "R_t",
        description = "Source termination resistance for critical damping",
        value       = Rt,
        units       = "Omega",
        specType    = "Interface",
    )
)

# source signal specification

specs.append(
    sl.specItem(
        "Vi_pp",
        description = "Maximum peak-peak input voltage",
        value       = Vi_pp,
        units       = "V",
        specType    = "Interface",
    )
)
specs.append(
    sl.specItem(
        "f_fp",
        description = "Maximum full-power frequency",
        value       = f_fp,
        units       = "Hz",
        specType    = "Interface",
    )
)

# Load impedance specification

specs.append(
    sl.specItem(
        "C_L",
        description = "Load capacitance",
        value       = CL,
        units       = "F",
        specType    = "Interface",
    )
)

# Load signal specification

specs.append(
    sl.specItem(
        "V_ADC_high",
        description = "Full-scale input voltage ADC",
        value       = V_ADC_high,
        units       = "V",
        specType    = "Interface",
    )
)

specs.append(
    sl.specItem(
        "V_ADC_low",
        description = "Zero-scale input voltage ADC",
        value       = V_ADC_low,
        units       = "V",
        specType    = "Interface",
    )
)

# Supply voltage specification
specs.append(
    sl.specItem(
        "V_DD_max",
        description = "Maximum supply voltage",
        value       = V_DD_max,
        units       = "V",
        specType    = "Interface",
    )
)
specs.append(
    sl.specItem(
        "V_DD_min",
        description = "Minimum supply voltage",
        value       = V_DD_min,
        units       = "V",
        specType    = "Interface",
    )
)

# Performance requirements (Transfer, Bandwidth, Resolution)

specs.append(
    sl.specItem(
        "tau_i",
        description = "Integration time constant",
        value       = tau_i,
        units       = "s",
        specType    = "performance",
    )
)
specs.append(
    sl.specItem(
        "f_min",
        description = "-3dB high-pass cut-off frequency",
        value       = f_min,
        units       = "Hz",
        specType    = "performance",
    )
)
specs.append(
    sl.specItem(
        "f_max",
        description = "-3dB low-pass cut-off frequency",
        value       = f_max,
        units       = "Hz",
        specType    = "performance",
    )
)
specs.append(
    sl.specItem(
        "V_onoise",
        description = "DIN A weighted output voltage noise",
        value       = V_onoise,
        units       = "V",
        specType    = "performance",
    )
)

# Costs specification

specs.append(
    sl.specItem(
        "P_max",
        description = "Maximum power dissipation at maximum supply voltage",
        value       = P_max,
        units       = "W",
        specType    = "Costs",
    )
)

# Environmental operating conditions

specs.append(
    sl.specItem(
        "T_min",
        description = "Minimum operating temperature",
        value       = T_min,
        units       = "Celsius",
        specType    = "Environment",
    )
)
specs.append(
    sl.specItem(
        "T_max",
        description = "Maximum operating temperature",
        value       = T_max,
        units       = "Celsius",
        specType    = "Environment",
    )
)
sl.specs2csv(specs, 'A1specs.csv')

# %%
sl.specs2html(specs)
# Out:
# <h3>Interface specification</h3>
# <table><a id="table_Interface"></a><caption>Table Interface specification </caption><tr><th class="left">symbol</th><th class="left">description</th><th class="left">value</th><th class="left">units</th></tr>
# <td class="left">$C_{L}$</td><td class="left">Load capacitance</td><td class="left">$10\cdot 10^{-12}$</td><td class="left">$\mathrm{F}$</td></tr>
# <td class="left">$C_{s}$</td><td class="left">Source capacitance</td><td class="left">$9.382\cdot 10^{-12}$</td><td class="left">$\mathrm{F}$</td></tr>
# <td class="left">$L_{s}$</td><td class="left">Source inductance</td><td class="left">$0.12$</td><td class="left">$\mathrm{H}$</td></tr>
# <td class="left">$R_{s}$</td><td class="left">Source resistance</td><td class="left">$875$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$R_{t}$</td><td class="left">Source termination resistance for critical damping</td><td class="left">$79.97\cdot 10^{3}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$V_{ADC high}$</td><td class="left">Full-scale input voltage ADC</td><td class="left">$0.9$</td><td class="left">$\mathrm{V}$</td></tr>
# <td class="left">$V_{ADC low}$</td><td class="left">Zero-scale input voltage ADC</td><td class="left">$0$</td><td class="left">$\mathrm{V}$</td></tr>
# <td class="left">$V_{DD max}$</td><td class="left">Maximum supply voltage</td><td class="left">$1.3$</td><td class="left">$\mathrm{V}$</td></tr>
# <td class="left">$V_{DD min}$</td><td class="left">Minimum supply voltage</td><td class="left">$1.1$</td><td class="left">$\mathrm{V}$</td></tr>
# <td class="left">$Vi_{pp}$</td><td class="left">Maximum peak-peak input voltage</td><td class="left">$0.1072$</td><td class="left">$\mathrm{V}$</td></tr>
# <td class="left">$f_{fp}$</td><td class="left">Maximum full-power frequency</td><td class="left">$5\cdot 10^{3}$</td><td class="left">$\mathrm{Hz}$</td></tr>
# </table>
# <h3>Costs specification</h3>
# <table><a id="table_Costs"></a><caption>Table Costs specification </caption><tr><th class="left">symbol</th><th class="left">description</th><th class="left">value</th><th class="left">units</th></tr>
# <td class="left">$P_{max}$</td><td class="left">Maximum power dissipation at maximum supply voltage</td><td class="left">$0.001$</td><td class="left">$\mathrm{W}$</td></tr>
# </table>
# <h3>Environment specification</h3>
# <table><a id="table_Environment"></a><caption>Table Environment specification </caption><tr><th class="left">symbol</th><th class="left">description</th><th class="left">value</th><th class="left">units</th></tr>
# <td class="left">$T_{max}$</td><td class="left">Maximum operating temperature</td><td class="left">$50$</td><td class="left">$\mathrm{Celsius}$</td></tr>
# <td class="left">$T_{min}$</td><td class="left">Minimum operating temperature</td><td class="left">$0$</td><td class="left">$\mathrm{Celsius}$</td></tr>
# </table>
# <h3>performance specification</h3>
# <table><a id="table_performance"></a><caption>Table performance specification </caption><tr><th class="left">symbol</th><th class="left">description</th><th class="left">value</th><th class="left">units</th></tr>
# <td class="left">$V_{onoise}$</td><td class="left">DIN A weighted output voltage noise</td><td class="left">$10.62\cdot 10^{-6}$</td><td class="left">$\mathrm{V}$</td></tr>
# <td class="left">$f_{max}$</td><td class="left">-3dB low-pass cut-off frequency</td><td class="left">$6\cdot 10^{3}$</td><td class="left">$\mathrm{Hz}$</td></tr>
# <td class="left">$f_{min}$</td><td class="left">-3dB high-pass cut-off frequency</td><td class="left">$600$</td><td class="left">$\mathrm{Hz}$</td></tr>
# <td class="left">$\tau_{i}$</td><td class="left">Integration time constant</td><td class="left">$16.06\cdot 10^{-6}$</td><td class="left">$\mathrm{s}$</td></tr>
# </table>

# %% [markdown]
# ## Verification
# Specification items that carry the same names as circuit parameters can be assigned to their corresponding circuit parameter.
# The DIN-A noise weighting function can be defined using the built-in definition.

# %%
sl.specs2circuit(specs, cir)
cir.defPar("DIN_A", sl.DIN_A())
sl.elementData2html(cir)
# Out:
# <table><caption>Table: Element data of expanded netlist 'fumo'</caption>
# <tr><th class="left">RefDes</th><th class="left">Nodes</th><th class="left">Refs</th><th class="left">Model</th><th class="left">Param</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">C1</td><td class = "left">1 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$C_{s}$</td><td class="left">$9.382\cdot 10^{-12}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">vinit</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">C2</td><td class = "left">out 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$C_{L}$</td><td class="left">$10\cdot 10^{-12}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">vinit</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">E1</td><td class = "left">out 0 1 0 </td><td class = "left"></td><td class = "left">E</td>
# <td class="left">value</td><td class="left">$\frac{1}{s \tau_{i}}$</td><td class="left">$\frac{6.226 \cdot 10^{4}}{s}$</td></tr>
# <tr><td class="left">E2</td><td class = "left">noise 0 out 0 </td><td class = "left"></td><td class = "left">E</td>
# <td class="left">value</td><td class="left">$DIN_{A}$</td><td class="left">$\frac{1.872 \cdot 10^{8} f^{4}}{\left(\left(f^{2} + 1.16 \cdot 10^{4}\right) \left(f^{2} + 5.445 \cdot 10^{5}\right)\right)^{0.5} \left(f^{2} + 424.4\right) \left(f^{2} + 1.487 \cdot 10^{8}\right)}$</td></tr>
# <tr><td class="left">L1</td><td class = "left">1 2 </td><td class = "left"></td><td class = "left">L</td>
# <td class="left">value</td><td class="left">$L_{s}$</td><td class="left">$0.12$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">iinit</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">R1</td><td class = "left">2 3 </td><td class = "left"></td><td class = "left">R</td>
# <td class="left">value</td><td class="left">$R_{s}$</td><td class="left">$875$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noisetemp</td><td class="left">$T$</td><td class="left">$300$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noiseflow</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvarlot</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">R2</td><td class = "left">1 0 </td><td class = "left"></td><td class = "left">R</td>
# <td class="left">value</td><td class="left">$R_{t}$</td><td class="left">$79.97\cdot 10^{3}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noisetemp</td><td class="left">$T$</td><td class="left">$300$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noiseflow</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvarlot</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">V1</td><td class = "left">3 0 </td><td class = "left"></td><td class = "left">V</td>
# <td class="left">value</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noise</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dc</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# </table>

# %% [markdown]
# ### Frequency characteristic
# The magnitude characteristic shows the signal integration and the critical damping at resonance.

# %%
transfer = sl.doLaplace(cir, pardefs="circuit", numeric=True)
sl.plotSweep("fumo_dBmag", "Magnitude of the transfer", transfer, 0.1, 1e3, 200, sweepScale="k", funcType="dBmag")
sl.img2html("fumo_dBmag.svg", 600)
# Out:
# <figure><img src="img/fumo_dBmag.svg" alt="" style="width:600px">
# </figure>

# %%
sl.plotSweep("fumo_phase", "Phase of the transfer", transfer, 0.1, 1e3, 200, sweepScale="k", funcType="phase")
sl.img2html("fumo_phase.svg", 600)
# Out:
# <figure><img src="img/fumo_phase.svg" alt="" style="width:600px">
# </figure>

# %% [markdown]
# The gain at the reference frequency must be:
# \begin{equation}
# A_\mathrm{A1} = 20\log{\frac{V_\mathrm{mic}}{V_i}}
# \end{equation}

# %%
sl.eqn2html("f_ref", f_ref, units="Hz")
# Out:
# \begin{equation}
# f_{ref}=1\cdot 10^{3}\,\left[ \mathrm{Hz}\right]
# \end{equation}

# %%
sl.eqn2html("A_A1", 20*log(V_mic/Vi)/log(10), units="dB")
# Out:
# \begin{equation}
# A_{A1}=19.92\,\left[ \mathrm{dB}\right]
# \end{equation}

# %% [markdown]
# Achieved:

# %%
gain = 20*log(Abs(transfer.laplace.subs(sl.ini.laplace, 2j*pi*f_ref)))/log(10)
sl.eqn2html("A_fumo", gain, units = "dB")
# Out:
# \begin{equation}
# A_{fumo}=19.83\,\left[ \mathrm{dB}\right]
# \end{equation}

# %% [markdown]
# **Question**
#
# What's the cause of the difference?
#
# Please check your answer!

# %% [markdown]
# ### Noise budget taken by signal source

# %%
RMSnoise = sl.rmsNoise(sl.doNoise(cir, pardefs="circuit", numeric=True, detector="V_noise"), "onoise", f_min, f_max)
sl.eqn2html("Vn_fumo", RMSnoise, units= "V")
# Out:
# \begin{equation}
# Vn_{fumo}=1.496\cdot 10^{-6}\,\left[ \mathrm{V}\right]
# \end{equation}

# %% [markdown]
# The relative part of the output noise taken by the source is:

# %%
sl.expr2html(RMSnoise/V_onoise)
# Out:
# $0.1409$
