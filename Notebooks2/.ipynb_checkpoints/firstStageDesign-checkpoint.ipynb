# %% [markdown]
# # Design of the controller's input CS stage's $g_m$ and $c_{iss}$
# ## Feedback circuit for noise design

# %%
import SLiCAP as sl
import sympy as sp
from WLI import updateModel, WLI
from SLiCAPmosNoise import process, specObject, doMOSnoiseDesign

sl.initProject('Hearing loop', notebook=True)

specs     = sl.csv2specs("fb_concept.csv")
spec_dict = sl.specs2dict(specs)
channel   = "P"
IC        = 0.5
    
baseName  = "feedbackConceptNoisyNullor{}18".format(channel.upper())
kicad_sch = "kicad/A1/{}.kicad_sch".format(baseName)
cir       = sl.makeCircuit(kicad_sch)

# Redefine some model equations.
cir, IC_sym, gm_sym = updateModel(cir, IC)

# Assign parameter definitions
sl.specs2circuit(specs, cir)

# Assign a noise budget (Contributions of: source, source termination, feedback network, and input stage)
B_n2      = 0
while B_n2 <= spec_dict["B_n1"].value or B_n2 >= 1:
    B_n2 = float(input("Please enter part of RMS output noise due to source resistance, termination resistance {} < B_n2 < {}"
                 .format(str(sp.N(spec_dict["B_n1"].value,3)), "1"))) 
sl.img2html(baseName + ".svg", 900)
# Out:
# Compiling library: SLiCAP.lib.
# Compiling library: SLiCAPmodels.lib.
# Creating netlist of kicad/A1/feedbackConceptNoisyNullorP18.kicad_sch using KiCAD
# Creating drawing-size SVG and PDF images of kicad/A1/feedbackConceptNoisyNullorP18.kicad_sch
# Plotted to '/home/anton/DATA/www/SEDwebsite/_build/SEDwebsite/EE4109-2025-2026/designExample/HearingLoop/Notebooks/img/feedbackConceptNoisyNullorP18.svg'.
# Done.
# Checking netlist: cir/feedbackConceptNoisyNullorP18.cir
# Compiling library: lib/SLiCAP_C18.lib.
# Please enter part of RMS output noise due to source resistance, termination resistance 0.400 < B_n2 < 1 0.8
# <figure><img src="img/feedbackConceptNoisyNullorP18.svg" alt="" style="width:900px">
# </figure>

# %% [markdown]
# ## Show expanded circuit data with parameters: $f$, $g_m$, and $c_{iss}$

# %%
sl.elementData2html(cir)
# Out:
# <table><caption>Table: Element data of expanded netlist 'feedbackConceptNoisyNullorP18'</caption>
# <tr><th class="left">RefDes</th><th class="left">Nodes</th><th class="left">Refs</th><th class="left">Model</th><th class="left">Param</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">C1</td><td class = "left">4 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$C_{s}$</td><td class="left">$9.382\cdot 10^{-12}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">vinit</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">C2</td><td class = "left">out 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$C_{L}$</td><td class="left">$10\cdot 10^{-12}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">vinit</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">C3</td><td class = "left">out 3 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$C_{i}$</td><td class="left">$2.142\cdot 10^{-9}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">vinit</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">E2</td><td class = "left">noise 0 out 0 </td><td class = "left"></td><td class = "left">E</td>
# <td class="left">value</td><td class="left">$DIN_{A}$</td><td class="left">$\frac{1.872 \cdot 10^{8} f^{4}}{\left(\left(f^{2} + 1.16 \cdot 10^{4}\right) \left(f^{2} + 5.445 \cdot 10^{5}\right)\right)^{0.5} \left(f^{2} + 424.4\right) \left(f^{2} + 1.487 \cdot 10^{8}\right)}$</td></tr>
# <tr><td class="left">G1_X1</td><td class = "left">int_X1 3 1_X1 int_X1 </td><td class = "left"></td><td class = "left">G</td>
# <td class="left">value</td><td class="left">$c_{iss X1} s$</td><td class="left">$c_{iss} s$</td></tr>
# <tr><td class="left">I1_X1</td><td class = "left">4 3 </td><td class = "left"></td><td class = "left">I</td>
# <td class="left">value</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noise</td><td class="left">$2 IG q$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dc</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">L1</td><td class = "left">4 1 </td><td class = "left"></td><td class = "left">L</td>
# <td class="left">value</td><td class="left">$L_{s}$</td><td class="left">$0.12$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">iinit</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">N1_X1</td><td class = "left">out 0 int_X1 3 </td><td class = "left"></td><td class = "left">N</td>
# <td></td><td></td><td></td><tr><tr><td class="left">R1</td><td class = "left">1 2 </td><td class = "left"></td><td class = "left">R</td>
# <td class="left">value</td><td class="left">$R_{s}$</td><td class="left">$875$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noisetemp</td><td class="left">$T$</td><td class="left">$300$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noiseflow</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvarlot</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">R2</td><td class = "left">4 0 </td><td class = "left"></td><td class = "left">R</td>
# <td class="left">value</td><td class="left">$R_{t}$</td><td class="left">$79.97\cdot 10^{3}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noisetemp</td><td class="left">$T$</td><td class="left">$300$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noiseflow</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvarlot</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">R3</td><td class = "left">3 0 </td><td class = "left"></td><td class = "left">R</td>
# <td class="left">value</td><td class="left">$R_{f}$</td><td class="left">$7.500\cdot 10^{3}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noisetemp</td><td class="left">$T$</td><td class="left">$300$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noiseflow</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvarlot</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">R4</td><td class = "left">out 3 </td><td class = "left"></td><td class = "left">R</td>
# <td class="left">value</td><td class="left">$R_{b}$</td><td class="left">$123.9\cdot 10^{3}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noisetemp</td><td class="left">$T$</td><td class="left">$300$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noiseflow</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvarlot</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">V1</td><td class = "left">2 0 </td><td class = "left"></td><td class = "left">V</td>
# <td class="left">value</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noise</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dc</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">V1_X1</td><td class = "left">4 1_X1 </td><td class = "left"></td><td class = "left">V</td>
# <td class="left">value</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noise</td><td class="left">$\frac{K_{F X1} \chi_{X1} f^{- AF_{P18}}}{C_{OX P18} c_{iss X1}}$</td><td class="left">$\frac{2.599 \cdot 10^{-26}}{c_{iss} f^{1.25}}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dc</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td class="left">V2_X1</td><td class = "left">1_X1 int_X1 </td><td class = "left"></td><td class = "left">V</td>
# <td class="left">value</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noise</td><td class="left">$\frac{4 \Gamma_{X1} N_{s P18} T k}{g_{m X1}}$</td><td class="left">$\frac{1.243 \cdot 10^{-20}}{g_{m}}$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dc</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$0$</td><td class="left">$0$</td></tr>
# </table>

# %% [markdown]
# ## Determine the spectrum of the weighted output noise as a function of $g_m$ and $c_{iss}$

# %%
# Declare symbolic variables
g_m, c_iss, f_T = sp.symbols("g_m, c_iss, f_T")
# Define frequency range
f_min           = spec_dict["f_min"].value
f_max           = spec_dict["f_max"].value
# Calculate the spectral density of the output noise; this may take a while
onoise          = sl.doNoise(cir, pardefs="circuit", numeric=True).onoise
onoise = sl.doNoise(cir, pardefs="circuit", numeric=True).onoise
sl.eqn2html("S_o", onoise, units="V**2/Hz")
# Out:
# \begin{equation}
# S_{o}=\frac{\left(6.25 \cdot 10^{86} f^{2} + 6.902 \cdot 10^{94}\right) \left(7.981 \cdot 10^{109} f^{2} + 1.075 \cdot 10^{116}\right)}{\left(6.944 \cdot 10^{85} f^{2} + 2.5 \cdot 10^{91}\right) \left(1.205 \cdot 10^{115} f^{4} + 1.623 \cdot 10^{121} f^{2} + 6.233 \cdot 10^{135}\right)} + \frac{6.14 \cdot 10^{204} f^{2} + 6.781 \cdot 10^{212}}{\left(6.944 \cdot 10^{85} f^{2} + 2.5 \cdot 10^{91}\right) \left(1.205 \cdot 10^{115} f^{4} + 1.623 \cdot 10^{121} f^{2} + 6.233 \cdot 10^{135}\right)} + \frac{8.986 \cdot 10^{77}}{6.944 \cdot 10^{85} f^{2} + 2.5 \cdot 10^{91}} + \frac{4.0 \cdot 10^{-29} \left(2.979 \cdot 10^{231} c_{iss}^{2} f^{6} - 1.943 \cdot 10^{239} c_{iss}^{2} f^{4} + 3.694 \cdot 10^{247} c_{iss}^{2} f^{2} + 5.565 \cdot 10^{220} c_{iss} f^{6} - 1.24 \cdot 10^{231} c_{iss} f^{4} - 1.209 \cdot 10^{238} c_{iss} f^{2} + 2.599 \cdot 10^{209} f^{6} + 2.905 \cdot 10^{217} f^{4} + 1.345 \cdot 10^{230} f^{2} + 1.485 \cdot 10^{238}\right)}{g_{m} \left(6.944 \cdot 10^{85} f^{2} + 2.5 \cdot 10^{91}\right) \left(1.205 \cdot 10^{115} f^{4} + 1.623 \cdot 10^{121} f^{2} + 6.233 \cdot 10^{135}\right)} + \frac{1.111 \cdot 10^{-41} \left(1.624 \cdot 10^{101} f^{2} + 1.794 \cdot 10^{109}\right)}{c_{iss} f^{1.25} \left(6.944 \cdot 10^{85} f^{2} + 2.5 \cdot 10^{91}\right)}\,\left[ \mathrm{\frac{V^2}{Hz}}\right]
# \end{equation}

# %% [markdown]
# ## Derive the noise design equation
# ### Get the output variance in ters of $g_m$ and $c_{iss}$

# %%
coeffs   = sl.integrated_monomial_coeffs(sp.expand(onoise), (g_m, c_iss), sl.ini.frequency, f_min, f_max)
ovar     = 0
for coeff in coeffs.keys():
    ovar += coeff * coeffs[coeff]
sl.eqn2html("sigma_o^2", ovar, units="V**2")
# Out:
# \begin{equation}
# \sigma_{o}^{2}=\frac{16.19 c_{iss}^{2}}{g_{m}} - \frac{1.36 \cdot 10^{-8} c_{iss}}{g_{m}} + 1.674 \cdot 10^{-11} + \frac{1.63 \cdot 10^{-15}}{g_{m}} + \frac{4.891 \cdot 10^{-25}}{c_{iss}}\,\left[ \mathrm{V^2}\right]
# \end{equation}

# %% [markdown]
# ### Write the output variance in terms of $f_T$ and $c_{iss}$
# This equation shows that a high cut-off frequency is benificial to the noise performance

# %%
ovar_fT         = sp.N(ovar.subs(g_m, 2 * sp.pi * f_T * c_iss))
sl.eqn2html("sigma_o^2", ovar_fT, units="V**2")
# Out:
# \begin{equation}
# \sigma_{o}^{2}=\frac{2.577 c_{iss}}{f_{T}} + 1.674 \cdot 10^{-11} - \frac{2.165 \cdot 10^{-9}}{f_{T}} + \frac{4.891 \cdot 10^{-25}}{c_{iss}} + \frac{2.595 \cdot 10^{-16}}{c_{iss} f_{T}}\,\left[ \mathrm{V^2}\right]
# \end{equation}

# %% [markdown]
# ### The noise equation for a specified RMS noise budget
# We will define a budget for the contribution of the controller's input stage to the total DIN A weighted output noise.
# and then solve $g_m$ after equating this budget with the obtained expression.

# %%
var_o = (B_n2 * spec_dict["V_onoise"].value)**2
# noise design equation
gm_ciss = sp.solve(ovar - var_o, g_m)[0]
sl.eqn2html("g_m(c_iss)", gm_ciss, units="S")
# Out:
# \begin{equation}
# g_{m}{\left(c_{iss} \right)}=\frac{1.136 \cdot 10^{8} c_{iss} \left(1.619 \cdot 10^{30} c_{iss}^{2} - 1.36 \cdot 10^{21} c_{iss} + 1.63 \cdot 10^{14}\right)}{6.297 \cdot 10^{26} c_{iss} - 5.558 \cdot 10^{12}}\,\left[ \mathrm{S}\right]
# \end{equation}

# %% [markdown]
# ## Find the lower limit of $c_{iss}$

# %%
num, den  = gm_ciss.as_numer_denom()
c_iss_Min = sp.solve(den, c_iss)[0]
if c_iss_Min <= 0:
    print("ERROR: no valid solution for this noise budget and inversion level!")
else:
    sl.eqn2html("c_iss_Min", c_iss_Min, units= "F")
c_iss_Min
# Out:
# 8.82724221179274e-15

# %% [markdown]
# ## Find the lowest current at the selected inversion coefficient
# ### Optimum $c_{iss}$

# %%
# Lowest current solution at this IC
diff_gm_ciss = sp.diff(gm_ciss, c_iss)
num, den     = diff_gm_ciss.as_numer_denom()
solutions    = sp.solve(num, c_iss)
c_iss_Opt1   = None
c_iss_Lim    = c_iss_Min
for sol in solutions:
    realpart = sp.re(sol)
    imagpart = sp.im(sol)
    if realpart > c_iss_Lim and sp.Abs(imagpart/realpart) < 1e-6:
        c_iss_Lim = realpart
        c_iss_Opt1 = realpart
sl.eqn2html("c_iss_Opt1", c_iss_Opt1, units="F")
# Out:
# \begin{equation}
# c_{iss Opt1}=422.6\cdot 10^{-12}\,\left[ \mathrm{F}\right]
# \end{equation}

# %% [markdown]
# ### Lowest $g_m$

# %%
# Minimum g_m
g_m_Min1 = gm_ciss.subs(c_iss, c_iss_Opt1)
sl.eqn2html("g_m_Min1", g_m_Min1, units="S")
# Out:
# \begin{equation}
# g_{m Min1}=29.37\cdot 10^{-6}\,\left[ \mathrm{S}\right]
# \end{equation}

# %% [markdown]
# ### Determine $W$, $L$ and $I_{DS}$
#
# Please **CHECK** if these values can be applied!
#
# How does the noise budget or the inversion coefficient change $W$, $L$ and $I_{DS}$?

# %%
W1, L1, IDS1 = WLI(cir, g_m_Min1, c_iss_Opt1, gm_sym, IC, channel)

# %%
sl.eqn2html("W", W1, units="m")
# Out:
# \begin{equation}
# W=0.001444\,\left[ \mathrm{m}\right]
# \end{equation}

# %%
sl.eqn2html("L", L1, units="m")
# Out:
# \begin{equation}
# L=78.60\cdot 10^{-6}\,\left[ \mathrm{m}\right]
# \end{equation}

# %%
sl.eqn2html("I_DS", IDS1, units="A")
# Out:
# \begin{equation}
# I_{DS}=-1.396\cdot 10^{-6}\,\left[ \mathrm{A}\right]
# \end{equation}

# %% [markdown]
# ## Find the lowest $g_m c_{iss}$ product
# ### Optimum $c_{iss}$

# %%
costs           = gm_ciss * c_iss
costs_diff_ciss = sp.diff(costs, c_iss)
num, den        = costs_diff_ciss.as_numer_denom()
solutions       = sp.solve(num, c_iss)
c_iss_Opt2      = None
c_iss_Lim       = c_iss_Min
for sol in solutions:
    realpart    = sp.re(sol)
    imagpart    = sp.im(sol)
    if realpart > c_iss_Lim and sp.Abs(imagpart/realpart) < 1e-6:
        c_iss_Lim  = realpart
        c_iss_Opt2 = realpart
sl.eqn2html("c_iss_Opt2", c_iss_Opt2, units="F")
# Out:
# \begin{equation}
# c_{iss Opt2}=17.65\cdot 10^{-15}\,\left[ \mathrm{F}\right]
# \end{equation}

# %% [markdown]
# ### Value of $g_m$

# %%
g_m_Min2 = gm_ciss.subs(c_iss, c_iss_Opt2)
sl.eqn2html("g_m_Min2", g_m_Min2, units="S")
# Out:
# \begin{equation}
# g_{m Min2}=58.85\cdot 10^{-6}\,\left[ \mathrm{S}\right]
# \end{equation}

# %% [markdown]
# ### Determine $W$, $L$ and $I_{DS}$
#
# Please **CHECK** if these values can be applied!
#
# How does the noise budget or the inversion coefficient change $W$, $L$ and $I_{DS}$?

# %%
W2, L2, IDS2 = WLI(cir, g_m_Min2, c_iss_Opt2, gm_sym, IC, channel)

# %%
sl.eqn2html("W", W2, units="m")
# Out:
# \begin{equation}
# W=8.004\cdot 10^{-6}\,\left[ \mathrm{m}\right]
# \end{equation}

# %%
sl.eqn2html("L", L2, units="m")
# Out:
# \begin{equation}
# L=217.4\cdot 10^{-9}\,\left[ \mathrm{m}\right]
# \end{equation}

# %%
sl.eqn2html("I_DS", IDS2, units="A")
# Out:
# \begin{equation}
# I_{DS}=-2.797\cdot 10^{-6}\,\left[ \mathrm{A}\right]
# \end{equation}

# %% [markdown]
# ## Store the results in the design database

# %%
specs.append(sl.specItem(
    "g_m{}1".format(channel.upper()),
    description = "Minimum transconductance {} channel input stage".format(channel.upper()),
    value       = g_m_Min1,
    units       = "S",
    specType    = "design")
)
specs.append(sl.specItem(
    "c_iss{}1".format(channel.upper()),
    description = "c_iss {}-channel input stage at minimum transconductance".format(channel.upper()),
    value       = c_iss_Opt1,
    units       = "S",
    specType    = "design")
)
specs.append(sl.specItem(
    "g_m{}2".format(channel.upper()),
    description = "Transconductance {} channel input stage at minimum g-c product".format(channel.upper()),
    value       = g_m_Min2,
    units       = "S",
    specType    = "design")
)
specs.append(sl.specItem(
    "c_iss{}2".format(channel.upper()),
    description = "c_iss {}-channel input stage at minimum g-c product".format(channel.upper()),
    value       = c_iss_Opt2,
    units       = "S",
    specType    = "design")
)
specs.append(sl.specItem(
    "W_i{}1".format(channel.upper()),
    description = "{}-channel input stage width at minimum transconductance".format(channel.upper()),
    value       = W1,
    units       = "m",
    specType    = "design")
)
specs.append(sl.specItem(
    "L_i{}1".format(channel.upper()),
    description = "{}-channel input stage length at minimum transconductance".format(channel.upper()),
    value       = L1,
    units       = "m",
    specType    = "design")
)
specs.append(sl.specItem(
    "I_i{}1".format(channel.upper()),
    description = "{}-channel input stage current at minimum transconductance".format(channel.upper()),
    value       = IDS1,
    units       = "A",
    specType    = "design")
)
specs.append(sl.specItem(
    "W_i{}2".format(channel.upper()),
    description = "{}-channel input stage width at minimum g-c product".format(channel.upper()),
    value       = W2,
    units       = "m",
    specType    = "design")
)
specs.append(sl.specItem(
    "L_i{}2".format(channel.upper()),
    description = "{}-channel input stage length at minimum g-c product".format(channel.upper()),
    value       = L2,
    units       = "m",
    specType    = "design")
)
specs.append(sl.specItem(
    "I_i{}2".format(channel.upper()),
    description = "{}-channel input stage current at minimum g-c product".format(channel.upper()),
    value       = IDS2,
    units       = "A",
    specType    = "design")
)
sl.specs2csv(specs, "fb_concept.csv")
sl.specs2html(specs, ["design"])
# Out:
# Warning: symbol g_mP1 already used, its definition will be overwritten!
# Warning: symbol c_issP1 already used, its definition will be overwritten!
# Warning: symbol g_mP2 already used, its definition will be overwritten!
# Warning: symbol c_issP2 already used, its definition will be overwritten!
# Warning: symbol W_iP1 already used, its definition will be overwritten!
# Warning: symbol L_iP1 already used, its definition will be overwritten!
# Warning: symbol I_iP1 already used, its definition will be overwritten!
# Warning: symbol W_iP2 already used, its definition will be overwritten!
# Warning: symbol L_iP2 already used, its definition will be overwritten!
# Warning: symbol I_iP2 already used, its definition will be overwritten!
# Warning: symbol g_mP1 already used, its definition will be overwritten!
# Warning: symbol c_issP1 already used, its definition will be overwritten!
# Warning: symbol g_mP2 already used, its definition will be overwritten!
# Warning: symbol c_issP2 already used, its definition will be overwritten!
# Warning: symbol W_iP1 already used, its definition will be overwritten!
# Warning: symbol L_iP1 already used, its definition will be overwritten!
# Warning: symbol I_iP1 already used, its definition will be overwritten!
# Warning: symbol W_iP2 already used, its definition will be overwritten!
# Warning: symbol L_iP2 already used, its definition will be overwritten!
# Warning: symbol I_iP2 already used, its definition will be overwritten!
# <h3>design specification</h3>
# <table><a id="table_design"></a><caption>Table design specification </caption><tr><th class="left">symbol</th><th class="left">description</th><th class="left">value</th><th class="left">units</th></tr>
# <td class="left">$B_{i1}$</td><td class="left">Relative budget for the current through the feedback network</td><td class="left">$0.1$</td><td></td></tr>
# <td class="left">$B_{n1}$</td><td class="left">Relative budget for contribution of source, termination and feedback network to the total weighted output noise</td><td class="left">$0.4$</td><td></td></tr>
# <td class="left">$C_{i}$</td><td class="left">Integrator capacitance</td><td class="left">$\frac{\tau_{i}}{R_{f}}$</td><td class="left">$\mathrm{F}$</td></tr>
# <td class="left">$I_{iN1}$</td><td class="left">N-channel input stage current at minimum transconductance</td><td class="left">$5.781\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$I_{iN2}$</td><td class="left">N-channel input stage current at minimum g-c product</td><td class="left">$11.44\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$I_{iP1}$</td><td class="left">P-channel input stage current at minimum transconductance</td><td class="left">$-1.396\cdot 10^{-6}$</td><td class="left">$\mathrm{A}$</td></tr>
# <td class="left">$I_{iP2}$</td><td class="left">P-channel input stage current at minimum g-c product</td><td class="left">$-2.797\cdot 10^{-6}$</td><td class="left">$\mathrm{A}$</td></tr>
# <td class="left">$L_{iN1}$</td><td class="left">N-channel input stage length at minimum transconductance</td><td class="left">$73\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$L_{iN2}$</td><td class="left">N-channel input stage length at minimum g-c product</td><td class="left">$6.900\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$L_{iP1}$</td><td class="left">P-channel input stage length at minimum transconductance</td><td class="left">$78.60\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$L_{iP2}$</td><td class="left">P-channel input stage length at minimum g-c product</td><td class="left">$217.4\cdot 10^{-9}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$R_{b}$</td><td class="left">Bias resistance</td><td class="left">$\frac{0.5}{\pi C_{i} f_{min}}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$R_{f}$</td><td class="left">Selected value of R_f</td><td class="left">$7.500\cdot 10^{3}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$R_{f max}$</td><td class="left">Maximum value of R_f</td><td class="left">$7.542\cdot 10^{3}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$R_{f min}$</td><td class="left">Minimum value of R_f</td><td class="left">$1.393\cdot 10^{3}$</td><td class="left">$\mathrm{\Omega}$</td></tr>
# <td class="left">$W_{iN1}$</td><td class="left">N-channel input stage width at minimum transconductance</td><td class="left">$0.004362$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$W_{iN2}$</td><td class="left">N-channel input stage width at minimum g-c product</td><td class="left">$816.1\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$W_{iP1}$</td><td class="left">P-channel input stage width at minimum transconductance</td><td class="left">$0.001444$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$W_{iP2}$</td><td class="left">P-channel input stage width at minimum g-c product</td><td class="left">$8.004\cdot 10^{-6}$</td><td class="left">$\mathrm{m}$</td></tr>
# <td class="left">$c_{issN1}$</td><td class="left">c_iss N-channel input stage at minimum transconductance</td><td class="left">$929.9\cdot 10^{-12}$</td><td class="left">$\mathrm{S}$</td></tr>
# <td class="left">$c_{issN2}$</td><td class="left">c_iss N-channel input stage at minimum g-c product</td><td class="left">$17.33\cdot 10^{-12}$</td><td class="left">$\mathrm{S}$</td></tr>
# <td class="left">$c_{issP1}$</td><td class="left">c_iss P-channel input stage at minimum transconductance</td><td class="left">$422.6\cdot 10^{-12}$</td><td class="left">$\mathrm{S}$</td></tr>
# <td class="left">$c_{issP2}$</td><td class="left">c_iss P-channel input stage at minimum g-c product</td><td class="left">$17.65\cdot 10^{-15}$</td><td class="left">$\mathrm{S}$</td></tr>
# <td class="left">$g_{mN1}$</td><td class="left">Minimum transconductance N channel input stage</td><td class="left">$140.4\cdot 10^{-6}$</td><td class="left">$\mathrm{S}$</td></tr>
# <td class="left">$g_{mN2}$</td><td class="left">Transconductance N channel input stage at minimum g-c product</td><td class="left">$277.9\cdot 10^{-6}$</td><td class="left">$\mathrm{S}$</td></tr>
# <td class="left">$g_{mP1}$</td><td class="left">Minimum transconductance P channel input stage</td><td class="left">$29.37\cdot 10^{-6}$</td><td class="left">$\mathrm{S}$</td></tr>
# <td class="left">$g_{mP2}$</td><td class="left">Transconductance P channel input stage at minimum g-c product</td><td class="left">$58.85\cdot 10^{-6}$</td><td class="left">$\mathrm{S}$</td></tr>
# </table>

# %% [markdown]
# ## Check the results

# %%
cir = sl.makeCircuit(kicad_sch)
sl.specs2circuit(specs, cir)
# Out:
# Creating netlist of kicad/A1/feedbackConceptNoisyNullorP18.kicad_sch using KiCAD
# Creating drawing-size SVG and PDF images of kicad/A1/feedbackConceptNoisyNullorP18.kicad_sch
# Plotted to '/home/anton/DATA/www/SEDwebsite/_build/SEDwebsite/EE4109-2025-2026/designExample/HearingLoop/Notebooks/img/feedbackConceptNoisyNullorP18.svg'.
# Done.
# Checking netlist: cir/feedbackConceptNoisyNullorP18.cir
# Compiling library: lib/SLiCAP_C18.lib.

# %% [markdown]
# ### Select values for de MOS device parameters

# %%
cir.defPar("W", W2)
cir.defPar("L", L2)
cir.defPar("ID", IDS2)

# %% [markdown]
# ### Perform noise analysis

# %%
noiseResult = sl.doNoise(cir, pardefs="circuit", detector="V_noise", numeric=True)
RMSnoise    = sl.rmsNoise(noiseResult, "onoise", f_min, f_max)
sl.eqn2html("V_noise", RMSnoise, units="V")
# Out:
# \begin{equation}
# V_{noise}=9.275\cdot 10^{-6}\,\left[ \mathrm{V}\right]
# \end{equation}

# %%
x=sp.Symbol("x")
sp.solve(16.19*x**2-1.36e-8*x+1.63e-15)
# Out:
# [4.20012353304509e-10 - 1.00251195190414e-8*I,
#  4.20012353304509e-10 + 1.00251195190414e-8*I]
